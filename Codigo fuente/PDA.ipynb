# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
finca= pd.read_csv("Dataprep.csv")

# %%
finca
# Out:
#     Fecha         Mes  Precipitación
# 0       8       junio           0.47
# 1       9       junio           0.85
# 2      10       junio           0.47
# 3      12       junio           0.25
# 4      13       junio           0.35
# 5      15       junio           0.15
# 6      17       junio           0.85
# 7      19       junio           0.18
# 8      20       junio           0.80
# 9      21       junio           0.96
# 10     26       junio           0.28
# 11     27       junio           0.29
# 12      2       julio           0.52
# 13      3       julio           1.01
# 14     13       julio           0.13
# 15     18       julio           0.19
# 16     19       julio           0.38
# 17     23       julio           0.36
# 18     26       julio           0.48
# 19     27       julio           0.45
# 20     28       julio           0.49
# 21      2      agosto           0.60
# 22      3      agosto           0.51
# 23      4      agosto           0.33
# ...

# %%
Finca.df[

# %%
junio=finca[finca.Mes=="junio"]

# %%
junio
# Out:
#     Fecha    Mes  Precipitación
# 0       8  junio           0.47
# 1       9  junio           0.85
# 2      10  junio           0.47
# 3      12  junio           0.25
# 4      13  junio           0.35
# 5      15  junio           0.15
# 6      17  junio           0.85
# 7      19  junio           0.18
# 8      20  junio           0.80
# 9      21  junio           0.96
# 10     26  junio           0.28
# 11     27  junio           0.29

# %%
julio=finca[finca.Mes=="julio"]

# %%
julio
# Out:
#     Fecha    Mes  Precipitación
# 12      2  julio           0.52
# 13      3  julio           1.01
# 14     13  julio           0.13
# 15     18  julio           0.19
# 16     19  julio           0.38
# 17     23  julio           0.36
# 18     26  julio           0.48
# 19     27  julio           0.45
# 20     28  julio           0.49

# %%
agosto=finca[finca.Mes=="agosto"]

# %%
agosto
# Out:
#     Fecha     Mes  Precipitación
# 21      2  agosto           0.60
# 22      3  agosto           0.51
# 23      4  agosto           0.33
# 24      5  agosto           0.37
# 25      7  agosto           0.55
# 26      8  agosto           0.39
# 27     10  agosto           0.11
# 28     11  agosto           0.23
# 29     12  agosto           1.13
# 30     16  agosto           0.28
# 31     21  agosto           2.32
# 32     23  agosto           0.47
# 33     25  agosto           2.08
# 34     27  agosto           0.61
# 35     31  agosto           0.54

# %%
septiembre=finca[finca.Mes=="septiembre"]

# %%
septiembre
# Out:
#     Fecha         Mes  Precipitación
# 36      1  septiembre           0.58
# 37      2  septiembre           1.00
# 38      7  septiembre           0.27
# 39      9  septiembre           0.71
# 40     10  septiembre           2.20
# 41     11  septiembre           1.47
# 42     12  septiembre           0.27
# 43     13  septiembre           0.27

# %%
plt.plot(junio.Precipitación, junio.Mes)
plt.plot(julio.Precipitación, julio.Mes)
plt.plot( agosto.Precipitación, agosto.Mes)
plt.plot(septiembre.Precipitación, septiembre.Mes)
plt.legend(["Junio","Julio","Agosto","Septiembre"])
plt.xlabel("Precipitación")
plt.xlim([0,2.5])
plt.ylabel("Mes")
plt.show()

# %%
# x = finca.Mes
# y = finca.Precipitación
fig, ax = plt.subplots()
ax.bar(finca.Mes, finca.Precipitación, width=0.5, edgecolor="black", linewidth=2)
#ax.bar(finca.Mes, finca.Precipitación)
ax.set_title("Grafico")
plt.xlabel('Mes')
plt.ylabel('Precipitación')
plt.ylim([0,2.5])
plt.show()
plt.close()
